# %% [markdown]
# ####
# The depth of closure is the depth beyond which significant sediment transport does not occur. It is a critical concept in coastal engineering for determining the limits of active beach profile changes. This depth is influenced by wave energy and sediment characteristics.
# This code calculates and compares the depth of closure (DoC)—the seaward limit of significant sediment movement—using several well-known empirical models. The DoC is a key parameter in coastal zone management, beach nourishment design, and shoreline evolution modeling.
#
#
# ⚙️ Input Parameters
# - H_s: Significant wave height (in meters)
# - T_s: Significant wave period (in seconds)
# - g: Acceleration due to gravity (9.81 m/s²)
#
# 🧪 Methods Implemented
# - Hallermeier Inner Limit (1978, 1981)
# Estimates DoC based on energetic but non-extreme wave conditions:
# d_{inner} = 2.28 H_s - 68.5 \frac{H_s^2}{g T_s^2}- Hallermeier Outer Limit
# Represents the maximum depth where sediment transport from storm waves may occur:
# d_{outer} = 1.75 H_s- Birkemeier (1985)
# Refined for U.S. East Coast field data:
# d = 1.57 H_s - 0.005 \frac{H_s^2}{g T_s^2}- Kraus et al. (1998)
# Matches the structure of Hallermeier’s inner formulation, emphasizing long-term changes:
# d = 2.28 H_s - 68.5 \frac{H_s^2}{g T_s^2}
#
# 📊 Output
# The script prints and visualizes the estimated depth of closure from each method using a bar chart. This allows for easy comparison of how different empirical models respond to the same wave inputs.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the wave parameters
H_s = 2.0# Significant wave height in meters
T_s = 8.0# Significant wave period in seconds
g = 9.81# Acceleration due to gravity in m/s²

# Hallermeier (1978, 1981) Method
def hallermeier_inner(H_s, T_s, g):
    d_inner = 2.28 * H_s - 68.5 * (H_s**2 / (g * T_s**2))
    return d_inner

def hallermeier_outer(H_s):
    d_outer = 1.75 * H_s
    return d_outer

# Birkemeier (1985) Method
def birkemeier(H_s, T_s, g):
    d_birkemeier = 1.57 * H_s - 0.005 * (H_s**2 / (g * T_s**2))
    return d_birkemeier

# Kraus et al. (1998) Method
def kraus(H_s, T_s, g):
    d_kraus = 2.28 * H_s - 68.5 * (H_s**2 / (g * T_s**2))
    return d_kraus

# Calculate depth of closure using different methods
doc_hallermeier_inner = hallermeier_inner(H_s, T_s, g)
doc_hallermeier_outer = hallermeier_outer(H_s)
doc_birkemeier = birkemeier(H_s, T_s, g)
doc_kraus = kraus(H_s, T_s, g)

# Print the results
print(f"Hallermeier Inner Depth of Closure= {doc_hallermeier_inner:.2f} meters")
print(f"Hallermeier Outer Depth of Closure= {doc_hallermeier_outer:.2f} meters")
print(f"Birkemeier Depth of Closure       = {doc_birkemeier:.2f} meters")
print(f"Kraus et al. Depth of Closure     = {doc_kraus:.2f} meters")

# Plot the results
methods = ['Hallermeier Inner', 'Hallermeier Outer', 'Birkemeier', 'Kraus et al.']
doc_values = [doc_hallermeier_inner, doc_hallermeier_outer, doc_birkemeier, doc_kraus]

plt.figure(figsize=(10, 5))
plt.bar(methods, doc_values)
plt.xlabel('Methods')
plt.ylabel('Depth of Closure (meters)')
plt.title('Depth of Closure Calculations Using Different Methods')
plt.xticks(rotation=45)
plt.show()
# Out:
# Hallermeier Inner Depth of Closure= 4.12 meters
# Hallermeier Outer Depth of Closure= 3.50 meters
# Birkemeier Depth of Closure       = 3.14 meters
# Kraus et al. Depth of Closure     = 4.12 meters

# %% [markdown]
# ### 🧠 Conceptual Understanding
#
# 1. **Define wave runup.**
#    Why is predicting runup height important in coastal engineering?
#
# 2. **Key Parameters**
#    What are the three main parameters used in most empirical runup models?
#
# 3. **Formula Interpretation**
#    In the general empirical formula
#    \[
#    R = C \left( a \beta \sqrt{HL} + \sqrt{ \frac{HL (b \beta^2 + c)}{2} } \right)
#    \]
#    what do the two terms inside the brackets represent physically?
#
# 4. **Energy Representation**
#    Why is the product \( H \times L \) used in estimating runup energy?
#
# 5. **Coefficient Meaning**
#    What does the coefficient \( C \) generally reflect in each model?
#
# 6. **Conceptual Understanding**
# - What does “depth of closure” refer to in coastal morphodynamics, and why is it important?
#
#
# - Which two input parameters are required for calculating depth of closure in most empirical formulas in your code?
#
#
# - Why is gravity g explicitly included in the formulations for Hallermeier, Birkemeier, and Kraus methods?

# %%
from jupyterquiz import display_quiz

quiz = [
    {
        "question": "Which two methods use the same formula for depth of closure?",
        "type": "many_choice",
        "answers": [
            {"answer": "Hallermeier Inner & Kraus", "correct": True, "feedback": "✅ Correct! They share the same structure."},
            {"answer": "Hallermeier Outer & Birkemeier", "correct": False, "feedback": "❌ Not quite."},
            {"answer": "Birkemeier & Kraus", "correct": False, "feedback": "❌ These differ in coefficients."}
        ]
    },
    {
        "question": "What does the term Hs² / (g × Ts²) represent?",
        "type": "many_choice",
        "answers": [
            {"answer": "Wave orbital energy", "correct": True, "feedback": "✅ Yes! It reflects wave energy at depth."},
            {"answer": "Sediment porosity", "correct": False, "feedback": "❌ Not related to porosity."},
            {"answer": "Tidal range", "correct": False, "feedback": "❌ Tidal range is not part of this term."}
        ]
    }
]

display_quiz(quiz)
# Out:
# <div id="dqvBpfguKngH" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #dqvBpfguKngH {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...
